# %%
# Correlation matrix for feature selection
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Calculate correlation between BTC returns and all indicators
returns_data = bitcoin_historical_data[['Close', 'RSI', 'MACD', 'Fear_and_Greed_Index']].pct_change()
correlation_matrix = returns_data.corr()

# Filter indicators with correlation > threshold (e.g., 0.5)
threshold = 0.5
significant_correlations = correlation_matrix[abs(correlation_matrix['Close']) > threshold]
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 # Correlation matrix for feature selection
#       2 import pandas as pd
# ----> 3 import seaborn as sns
#       4 import matplotlib.pyplot as plt
#       6 # Calculate correlation between BTC returns and all indicators
#
# ModuleNotFoundError: No module named 'seaborn'
